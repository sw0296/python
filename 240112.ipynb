# %%
import requests

response = requests.get("http://shopping.naver.com/home")
html = response.text
print(html)
# Out:
# <!DOCTYPE html><html lang="ko"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, minimum-scale=1.0, maximum-scale=1.0, user-scalable=no, viewport-fit=cover"/><title>네이버쇼핑</title><meta property="og:title" content="네이버쇼핑"/><meta property="og:image" content="https://shopv.pstatic.net/web/cnsv/m/im/ogtag/01_nshopping.png"/><meta property="og:description" content="온/오프라인 상품 탐색과 쇼핑정보, 가격비교, 제품리뷰 등을 만나보세요"/><meta property="description" content="온/오프라인 상품 탐색과 쇼핑정보, 가격비교, 제품리뷰 등을 만나보세요"/><meta property="og:locale" content="ko_KR"/><meta property="og:type" content="website"/><link rel="shortcut icon" href="https://shopv.pstatic.net/web/r/20240111142011/_next/static/ico/favicon_shopping.ico"/><link rel="apple-touch-icon-precomposed" href="https://shopv.pstatic.net/web/r/20240111142011/_next/static/ico/favicon_shopping.ico"/><meta name="apple-mobile-web-app-title" content="네이버쇼핑"/><meta name="application-name" content="네이버쇼핑"/><link rel="stylesheet"
# ...

# %%
pip install bs4
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1264 sha256=6710bf51af0fb089e1456a632368573f31849f6be6a70ae6b158e367fc6c48ce
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\d4\c8\5b\b5be9c20e5e4503d04a6eac8a3cd5c2393505c29f02bea0960
# Successfully built bs4
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(html, 'html.parser')

soup.select_one('div')  #태그
# Out:
# <div id="FIRST_LAYER_ID"></div>

# %%
soup.select_one('.home') #클래스
# Out:
# <div class="home"><div style="display:none"><div class="pcHeader_header__eETRe"><div class="header_fix"><div class="_gnb_gnb_2C24o" id="gnb-gnb"><div class="_gnb_skip_navigation_3S3aO" id="u_skip"><button class="_gnb_link_3K4IH"><span class="_gnb_text_3gc0U">메인 메뉴로 바로가기</span></button><button class="_gnb_link_3K4IH" data-id="content" data-vertical="HOME"><span class="_gnb_text_3gc0U">본문으로 바로가기</span></button></div><div class="_gnb_header_area_150KE"><div class="header_fix"><div class="_gnbHeader_gnb_header_aiw0M"><div class="_gnbHeader_header_inner_2hQhW"><div class="_gnbHeader_main_site_2NLsV"><a class="_gnbHeader_link_wW48B N=a:GNB.naver" href="https://www.naver.com" title="나의 경쟁력, 네이버"><svg class="_gnbHeader_icon_naver_2Akrc" fill="none" height="13" viewbox="0 0 48 13" width="48"><g clip-rule="evenodd" fill="#fff" fill-rule="evenodd" filter="url(#TextNaver48x13White_svg__vxvlo35tza)"><path d="M14.663 2.5l-3.31 7.957h2.813l.4-1.053h3.173l.4 1.053h2.814L17.643 2.5h-2.98zm1.49 2.507l
# ...

# %%
soup.select_one('.blind')
# Out:
# <span class="blind" lang="en">NAVER</span>

# %%
soup.select_one('#FIRST_LAYER_ID')  #    #은 아이디를 검색하는 거다
# Out:
# <div id="FIRST_LAYER_ID"></div>

# %%
soup.select_one('div > .blind')
# Out:
# <h2 class="blind">검색영역</h2>

# %%
soup.select_one('div .blind')
# Out:
# <span class="blind" lang="en">NAVER</span>

# %%
soup.select(".productCardResponsive_image__yk4BY")
# Out:
# [<img alt="" class="productCardResponsive_image__yk4BY" data-src="https://shop-phinf.pstatic.net/20240111_8/1704938272715yaSmu_JPEG/2_1.jpg?type=f300" src="https://shop-phinf.pstatic.net/20240111_8/1704938272715yaSmu_JPEG/2_1.jpg?type=f300" style="height:"/>,
#  <img alt="" class="productCardResponsive_image__yk4BY" data-src="https://shop-phinf.pstatic.net/20240111_234/1704938275986IfQQ2_JPEG/2_2.jpg?type=f300" src="https://shop-phinf.pstatic.net/20240111_234/1704938275986IfQQ2_JPEG/2_2.jpg?type=f300" style="height:"/>,
#  <img alt="" class="productCardResponsive_image__yk4BY" data-src="https://shop-phinf.pstatic.net/20240111_111/1704938291108z4EE2_JPEG/2_7.jpg?type=f300" src="https://shop-phinf.pstatic.net/20240111_111/1704938291108z4EE2_JPEG/2_7.jpg?type=f300" style="height:"/>,
# ...

# %%
soup.select(".productCardResponsive_image__yk4BY")[5].text
# Out:
# ''

# %%
soup.select_one(".productCardResponsive_image__yk4BY")
# Out:
# <img alt="" class="productCardResponsive_image__yk4BY" data-src="https://shop-phinf.pstatic.net/20240111_8/1704938272715yaSmu_JPEG/2_1.jpg?type=f300" src="https://shop-phinf.pstatic.net/20240111_8/1704938272715yaSmu_JPEG/2_1.jpg?type=f300" style="height:"/>

# %%
soup.select_one(".productCardResponsive_image__yk4BY")['src']
# Out:
# 'https://shop-phinf.pstatic.net/20240111_8/1704938272715yaSmu_JPEG/2_1.jpg?type=f300'

# %%
soup.select_one(".productCardResponsive_image__yk4BY")["href"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 soup.select_one(".productCardResponsive_image__yk4BY")["href"]
#
# File c:\Users\User\anaconda3\Lib\site-packages\bs4\element.py:1573, in Tag.__getitem__(self, key)
#    1570 def __getitem__(self, key):
#    1571     """tag[key] returns the value of the 'key' attribute for the Tag,
#    1572     and throws an exception if it's not there."""
# -> 1573     return self.attrs[key]
#
# KeyError: 'href'

# %%
soup.select_one(".productCardResponsive_image__yk4BY")
# Out:
# <img alt="" class="productCardResponsive_image__yk4BY" data-src="https://shop-phinf.pstatic.net/20240111_8/1704938272715yaSmu_JPEG/2_1.jpg?type=f300" src="https://shop-phinf.pstatic.net/20240111_8/1704938272715yaSmu_JPEG/2_1.jpg?type=f300" style="height:"/>

# %%
soup.select(".shoppingCategoryListResponsive_text__rBAL0")[7].text
# Out:
# '럭셔리'

# %%
soup.select(".shoppingCategoryListResponsive_text__rBAL0")
# Out:
# [<div class="shoppingCategoryListResponsive_text__rBAL0">도착보장</div>,
#  <div class="shoppingCategoryListResponsive_text__rBAL0">쇼핑라이브</div>,
#  <div class="shoppingCategoryListResponsive_text__rBAL0">원쁠딜</div>,
#  <div class="shoppingCategoryListResponsive_text__rBAL0">패션타운</div>,
#  <div class="shoppingCategoryListResponsive_text__rBAL0">장보기</div>,
#  <div class="shoppingCategoryListResponsive_text__rBAL0">선물샵</div>,
#  <div class="shoppingCategoryListResponsive_text__rBAL0">멤버십특가</div>,
#  <div class="shoppingCategoryListResponsive_text__rBAL0">럭셔리</div>,
#  <div class="shoppingCategoryListResponsive_text__rBAL0">미스터</div>,
#  <div class="shoppingCategoryListResponsive_text__rBAL0">리빙윈도</div>,
#  <div class="shoppingCategoryListResponsive_text__rBAL0">푸드윈도</div>,
#  <div class="shoppingCategoryListResponsive_text__rBAL0">키즈윈도</div>,
#  <div class="shoppingCategoryListResponsive_text__rBAL0">펫</div>,
#  <div class="shoppingCategoryListResponsive_text__rBAL0">천원샵</div>,
# ...

# %%
#실습
import requests
from bs4 import BeautifulSoup


response = requests.get("https://search.naver.com/search.naver?where=news&sm=tab_pge&query=ai&start=1")
html = response.text
#print(html)
soup = BeautifulSoup(html, 'html.parser')
articles=soup.select(".news_area")
#print(articles)

news_title = []
for i in articles:
    news_title=i.select_one(".news_tit")
    .append(i.attrs["title"])
news_title
# Out:
# [<div class="news_contents"> <a class="dsc_thumb" href="http://www.newsis.com/view/?id=NISX20240112_0002589917&amp;cID=10201&amp;pID=10200" onclick="return goOtherCR(this, 'a=nws*h.img&amp;r=1&amp;i=88000127_000000000000000012315169&amp;g=003.0012315169&amp;u='+urlencode(this.href));" target="_blank"><img alt="초성검색 꼼수에 뚫렸" class="thumb" data-lazysrc="https://search.pstatic.net/common/?src=https%3A%2F%2Fimgnews.pstatic.net%2Fimage%2Forigin%2F003%2F2024%2F01%2F12%2F12315169.jpg&amp;type=f200_200&amp;expire=2&amp;refresh=true" height="104" onerror="this.parentNode.style.display='none';" src="..." width="104"/></a> <a class="news_tit" href="http://www.newsis.com/view/?id=NISX20240112_0002589917&amp;cID=10201&amp;pID=10200" onclick="return goOtherCR(this, 'a=nws*h.tit&amp;r=1&amp;i=88000127_000000000000000012315169&amp;g=003.0012315169&amp;u='+urlencode(this.href));" target="_blank" title="초성검색 꼼수에 뚫렸던 '좀비마약'…AI도입해 차단한다">초성검색 꼼수에 뚫렸던 '좀비마약'…<mark>AI</mark>도입해 차단한다</a> <div class="news_dsc
# ...

# %%
soup.select(".return goOtherCR(this, 'a=nws*h.tit&r=1&i=88000127_000000000000000012315169&g=003.0012315169&u='+urlencode(this.href)")
# Out:
# ---------------------------------------------------------------------------
# SelectorSyntaxError                       Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 soup.select(".return goOtherCR(this, 'a=nws*h.tit&r=1&i=88000127_000000000000000012315169&g=003.0012315169&u='+urlencode(this.href)")
#
# File c:\Users\User\anaconda3\Lib\site-packages\bs4\element.py:2111, in Tag.select(self, selector, namespaces, limit, **kwargs)
#    2091 def select(self, selector, namespaces=None, limit=None, **kwargs):
#    2092     """Perform a CSS selection operation on the current element.
#    2093
#    2094     This uses the SoupSieve library.
#    (...)
#    2109     :rtype: bs4.element.ResultSet
#    2110     """
# -> 2111     return self.css.select(selector, namespaces, limit, **kwargs)
#
# File c:\Users\User\anaconda3\Lib\site-packages\bs4\css.py:162, in CSS.select(self, select, namespaces, limit, flags, **kwargs)
#     158 if limit is None:
#     159     limit = 0
# ...

# %%
import requests
from bs4 import BeautifulSoup

# %%
soup.select()
# Out:
# <div id="nxtt_div" style="display:none;position:absolute;border-width:0;z-index:11000"></div>

# %%
soup.select(".home")
# Out:
# [<div class="home"><div style="display:none"><div class="pcHeader_header__eETRe"><div class="header_fix"><div class="_gnb_gnb_2C24o" id="gnb-gnb"><div class="_gnb_skip_navigation_3S3aO" id="u_skip"><button class="_gnb_link_3K4IH"><span class="_gnb_text_3gc0U">메인 메뉴로 바로가기</span></button><button class="_gnb_link_3K4IH" data-id="content" data-vertical="HOME"><span class="_gnb_text_3gc0U">본문으로 바로가기</span></button></div><div class="_gnb_header_area_150KE"><div class="header_fix"><div class="_gnbHeader_gnb_header_aiw0M"><div class="_gnbHeader_header_inner_2hQhW"><div class="_gnbHeader_main_site_2NLsV"><a class="_gnbHeader_link_wW48B N=a:GNB.naver" href="https://www.naver.com" title="나의 경쟁력, 네이버"><svg class="_gnbHeader_icon_naver_2Akrc" fill="none" height="13" viewbox="0 0 48 13" width="48"><g clip-rule="evenodd" fill="#fff" fill-rule="evenodd" filter="url(#TextNaver48x13White_svg__vxvlo35tza)"><path d="M14.663 2.5l-3.31 7.957h2.813l.4-1.053h3.173l.4 1.053h2.814L17.643 2.5h-2.98zm1.49 2.507
# ...

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import openpyxl

wb = openpyxl.Workbook()

ws = wb.create_sheet("codingon")

ws['A1'] = '이름'
ws['B1'] = '영어이름'

ws['A2'] = '이성우'
ws['B2'] = 'sw'

wb.save('./codingon.xlsx')

# %%
from openpyxl import Workbook

# Create a new Workbook
wb = Workbook()

# Create a worksheet
ws = wb.active
ws.title = 'Data'

# Data to be added
data = [
    ['Name', 'Age'],
    ['Alice', 30],
    ['Bob', 25],
    ['Charlie', 35]
]

# Add data to the worksheet using append
for row in data:
    ws.append(row)

# Save the workbook
wb.save('append_le.xlsx')

# %%
pip install selenium
# Out:
# ...
#   Obtaining dependency information for selenium from https://files.pythonhosted.org/packages/dc/72/96b5afa16908f9abc7c24b70adfd3a46c9740eb728ddfeab28379e38eaf9/selenium-4.16.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for trio~=0.17 from https://files.pythonhosted.org/packages/14/fb/9299cf74953f473a15accfdbe2c15218e766bae8c796f2567c83bae03e98/trio-0.24.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for trio-websocket~=0.9 from https://files.pythonhosted.org/packages/48/be/a9ae5f50cad5b6f85bd2574c2c923730098530096e170c1ce7452394d7aa/trio_websocket-0.11.1-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for outcome from https://files.pythonhosted.org/packages/55/8b/5ab7257531a5d830fc8000c476e63c935488d74609b50f9384a643ec0a62/outcome-1.3.0.post0-py2.py3-none-any.whl.metadata
# ...
#      ---------------------------------------- 0.0/58.3 kB ? eta -:--:--
#      ---------------------------------------- 58.3/58.3 kB 3.0 MB/s eta 0:00:00
# ...

# %%
pip install webdriver_manager
# Out:
# ...
#   Obtaining dependency information for webdriver_manager from https://files.pythonhosted.org/packages/b1/51/b5c11cf739ac4eecde611794a0ec9df420d0239d51e73bc19eb44f02b48b/webdriver_manager-4.0.1-py2.py3-none-any.whl.metadata
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

chrome_options = Options()
chrome_options.add_experimental_option("detach", True)

service = Service(executable_path=ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=chrome_options)

driver.get("https://www.naver.com")

# %%
from selenium.webdriver.common.by import By
login = driver.find_element(By.CLASS_NAME, "MyView-module__my_login___tOTgr")
login.click()

# %%
id = driver.find_elements(By.CLASS_NAME, "input_text")[0]
id.click()
id.send_keys("gamechamp00@naver.com")

# %%
input_elm.send_keys(Keys.RETURN)

# %%
#리더님 정답 엑셀 전까지
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from time import sleep

chrome_options = Options()
chrome_options.add_experimental_option("detach", True)

service = Service(executable_path=ChromeDriverManager().install())

driver = webdriver.Chrome(service=service, options=chrome_options)
driver.get("https://shopping.naver.com/home")

sleep(3)
search = driver.find_element(By.CSS_SELECTOR, '#gnb-gnb > div > div._combineHeader_inner_2Uy4J > button > span')
search.click()
sleep(3)
input_elm = driver.find_element(By.CSS_SELECTOR, '#input_text')
input_elm.send_keys('자두')
input_elm.send_keys(Keys.RETURN)
sleep(3)

current_height = driver.execute_script("return window.scrollY")

while True:
    driver.find_element(By.CSS_SELECTOR, 'body').send_keys(Keys.END)
    sleep(1)
    
    scrolled_height = driver.execute_script("return window.scrollY")
    
    if (current_height == scrolled_height):
        break
    
    current_height = scrolled_height

products = driver.find_elements(By.CSS_SELECTOR, '.product_list_item__b84TO')

for product in products:
    title = product.find_element(By.CSS_SELECTOR, '.product_info_tit__c5_pb').text
    print(f"제목 {title}")
    price = product.find_element(By.CSS_SELECTOR, '.product_num__iQsWh').text
    print(f"가격 {price}")
    # link = product.find_element(By.TAG_NAME, 'a').get_attribute('href')
    link = product.find_element(By.XPATH, '//a[contains(text(), "상품 바로가기")]').get_attribute('href')
    print(f"링크 {link}")
